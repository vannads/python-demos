# %% [markdown]
# # K Means Clustering Project
#
# For this project we will attempt to use KMeans Clustering to cluster Universities into to two groups, Private and Public.
#
# ___
# It is **very important to note, we actually have the labels for this data set, but we will NOT use them for the KMeans clustering algorithm, since that is an unsupervised learning algorithm.**
#
# When using the Kmeans algorithm under normal circumstances, it is because you don't have labels. In this case we will use the labels to try to get an idea of how well the algorithm performed, but you won't usually do this for Kmeans, so the classification report and confusion matrix at the end of this project, don't truly make sense in a real world setting!.
# ___
#
# ## The Data
#
# We will use a data frame with 777 observations on the following 18 variables.
# * Private A factor with levels No and Yes indicating private or public university
# * Apps Number of applications received
# * Accept Number of applications accepted
# * Enroll Number of new students enrolled
# * Top10perc Pct. new students from top 10% of H.S. class
# * Top25perc Pct. new students from top 25% of H.S. class
# * F.Undergrad Number of fulltime undergraduates
# * P.Undergrad Number of parttime undergraduates
# * Outstate Out-of-state tuition
# * Room.Board Room and board costs
# * Books Estimated book costs
# * Personal Estimated personal spending
# * PhD Pct. of faculty with Ph.D.’s
# * Terminal Pct. of faculty with terminal degree
# * S.F.Ratio Student/faculty ratio
# * perc.alumni Pct. alumni who donate
# * Expend Instructional expenditure per student
# * Grad.Rate Graduation rate

# %% [markdown]
# ## Import Libraries
#
# ** Import the libraries you usually use for data analysis.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the Data

# %% [markdown]
# ** Read in the College_Data file using read_csv. Figure out how to set the first column as the index.**

# %%
# !ls -l
# Out:
# total 21488
# -rw-rw-r--@  1 sathisanvannadil  staff   543160 Apr  8 16:27 1_Linear_Regression_Ecommerce_Project.ipynb
# -rw-r--r--   1 sathisanvannadil  staff   735835 Apr  8 16:33 1_Linear_Regression_house_price.ipynb
# -rw-r--r--   1 sathisanvannadil  staff   559905 Apr 11 15:28 2_Logistic_Regression_Advertising_Project.ipynb
# -rw-r--r--   1 sathisanvannadil  staff   123999 Apr  8 16:35 2_Logistic_Regression_Titanic_Survivor_V1.0.ipynb
# -rw-r--r--   1 sathisanvannadil  staff   124258 Apr 11 15:29 2_Logistic_Regression_Titanic_Survivor_V2.0.ipynb
# -rw-r--r--   1 sathisanvannadil  staff   168834 Apr 11 15:29 2_Logistic_Regression_Titanic_Survivor_V3.0.ipynb
# -rw-r--r--   1 sathisanvannadil  staff  2279466 Apr 11 15:29 3_K_Nearest_Neighbours_Project_V1.0.ipynb
# -rw-r--r--   1 sathisanvannadil  staff    48108 Apr 11 15:30 3_K_Nearest_Neighbours_V1.0.ipynb
# -rw-r--r--   1 sathisanvannadil  staff    78859 Apr 12 18:08 4_Decision_Trees_and_Random_Forests.ipynb
# -rw-r--r--   1 sathisanvannadil  staff   204607 Apr 15 11:49 5_Decision_Trees_and_Random_Forests_Project-V2.0.ipynb
# -rw-r--r--   1 sathisanvannadil  staff   205453 Apr 15 21:55 5_Decision_Trees_and_Random_Forests_Project_V1.0.ipynb
# -rw-r--r--   1 sathisanvannadil  staff  5449385 Apr 18 11:22 6_Support_Vector_Machines_Project_V1.0.ipynb
# -rw-r--r--   1 sathisanvannadil  staff    51905 Apr 16 18:10 6_Support_Vector_Machines_V1.0.ipynb
# -rw-rw-r--@  1 sathisanvannadil  staff   169210 Aug 31  2018 7_K Means_Clustering Project - Solutions.ipynb
# -rw-rw-r--@  1 sathisanvannadil  staff    74226 Apr 29 12:08 7_K_Means_Clustering_Example.ipynb
# -rw-rw-r--@  1 sathisanvannadil  staff    69480 Apr 29 12:18 7_K_Means_Clustering_Project.ipynb
# -rw-rw-r--@  1 sathisanvannadil  staff    78070 Aug 31  2018 College_Data
# drwxr-xr-x  12 sathisanvannadil  staff      384 Apr 18 11:24 Data

# %%
gdata = pd.read_csv("College_Data")

# %% [markdown]
# **Check the head of the data**

# %%
gdata.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0   70        78       18.1           12    7041         60
# 1   29        30       12.2           16   10527         56
# 2   53        66       12.9           30    8735         54
# 3   92        97        7.7           37   19016         59
# 4   76        72       11.9            2   10922         15

# %% [markdown]
# ** Check the info() and describe() methods on the data.**

# %%
gdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 19 columns):
# Unnamed: 0     777 non-null object
# Private        777 non-null object
# Apps           777 non-null int64
# Accept         777 non-null int64
# Enroll         777 non-null int64
# Top10perc      777 non-null int64
# Top25perc      777 non-null int64
# F.Undergrad    777 non-null int64
# P.Undergrad    777 non-null int64
# Outstate       777 non-null int64
# Room.Board     777 non-null int64
# Books          777 non-null int64
# Personal       777 non-null int64
# PhD            777 non-null int64
# Terminal       777 non-null int64
# S.F.Ratio      777 non-null float64
# perc.alumni    777 non-null int64
# Expend         777 non-null int64
# Grad.Rate      777 non-null int64
# dtypes: float64(1), int64(16), object(2)
# memory usage: 115.5+ KB

# %%
gdata.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# min      139.000000      1.000000   2340.000000  1780.000000    96.000000
# 25%      992.000000     95.000000   7320.000000  3597.000000   470.000000
# 50%     1707.000000    353.000000   9990.000000  4200.000000   500.000000
# 75%     4005.000000    967.000000  12925.000000  5050.000000   600.000000
# max    31643.000000  21836.000000  21700.000000  8124.000000  2340.000000
#
#           Personal         PhD    Terminal   S.F.Ratio  perc.alumni  \
# count   777.000000  777.000000  777.000000  777.000000   777.000000
# mean   1340.642214   72.660232   79.702703   14.089704    22.743887
# std     677.071454   16.328155   14.722359    3.958349    12.391801
# min     250.000000    8.000000   24.000000    2.500000     0.000000
# 25%     850.000000   62.000000   71.000000   11.500000    13.000000
# 50%    1200.000000   75.000000   82.000000   13.600000    21.000000
# 75%    1700.000000   85.000000   92.000000   16.500000    31.000000
# max    6800.000000  103.000000  100.000000   39.800000    64.000000
#
#              Expend  Grad.Rate
# count    777.000000  777.00000
# mean    9660.171171   65.46332
# std     5221.768440   17.17771
# min     3186.000000   10.00000
# 25%     6751.000000   53.00000
# 50%     8377.000000   65.00000
# 75%    10830.000000   78.00000
# max    56233.000000  118.00000

# %% [markdown]
# ## EDA
#
# It's time to create some data visualizations!
#
# ** Create a scatterplot of Grad.Rate versus Room.Board where the points are colored by the Private column. **

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="Grad.Rate", y="Room.Board", hue='Private', data=gdata)
plt.show()

# %% [markdown]
# **Create a scatterplot of F.Undergrad versus Outstate where the points are colored by the Private column.**

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='F.Undergrad', y='Outstate', hue='Private', data=gdata)
plt.show()

# %% [markdown]
# ** Create a stacked histogram showing Out of State Tuition based on the Private column. Try doing this using [sns.FacetGrid](https://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.FacetGrid.html). If that is too tricky, see if you can do it just by using two instances of pandas.plot(kind='hist'). **

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(gdata, hue="Private", palette="coolwarm", size=6, aspect=2, legend_out=True)
g = g.map(plt.hist, 'Outstate', bins=20, alpha=0.7)

# %% [markdown]
# **Create a similar histogram for the Grad.Rate column.**

# %% [markdown]
# ** Notice how there seems to be a private school with a graduation rate of higher than 100%.What is the name of that school?**

# %% [markdown]
# ** Set that school's graduation rate to 100 so it makes sense. You may get a warning not an error) when doing this operation, so use dataframe operations or just re-do the histogram visualization to make sure it actually went through.**

# %% [markdown]
# ## K Means Cluster Creation
#
# Now it is time to create the Cluster labels!
#
# ** Import KMeans from SciKit Learn.**

# %% [markdown]
# ** Create an instance of a K Means model with 2 clusters.**

# %% [markdown]
# **Fit the model to all the data except for the Private label.**

# %% [markdown]
# ** What are the cluster center vectors?**

# %% [markdown]
# ## Evaluation
#
# There is no perfect way to evaluate clustering if you don't have the labels, however since this is just an exercise, we do have the labels, so we take advantage of this to evaluate our clusters, keep in mind, you usually won't have this luxury in the real world.
#
# ** Create a new column for df called 'Cluster', which is a 1 for a Private school, and a 0 for a public school.**

# %% [markdown]
# ** Create a confusion matrix and classification report to see how well the Kmeans clustering worked without being given any labels.**

# %% [markdown]
# Not so bad considering the algorithm is purely using the features to cluster the universities into 2 distinct groups! Hopefully you can begin to see how K Means is useful for clustering un-labeled data!
#
# ## Great Job!
