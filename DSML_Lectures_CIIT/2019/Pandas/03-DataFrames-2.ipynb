# %% [markdown]
# # DataFrames
#
# DataFrames are the workhorse of pandas and are directly inspired by the R programming language. We can think of a DataFrame as a bunch of Series objects put together to share the same index. Let's use pandas to explore this topic!

# %% [markdown]
# <img src="iloc_loc.png">
# Ref: https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/

# %% [raw]
# #--------------------------------------------
# #         Selections using iloc
# #--------------------------------------------
#
# # Rows:
# df.iloc[0] # first row of dataframe
# df.iloc[1] # second row of dataframe
# df.iloc[-1] # last row of dataframe
#
# # Columns:
# df.iloc[:,0] # first column of dataframe
# df.iloc[:,1] # second column of dataframe
# df.iloc[:,-1] # last column of dataframe
#
#
# # Multiple row and column selections using iloc and DataFrame
# data.iloc[0:5] # first five rows of dataframe
# data.iloc[:, 0:2] # first two columns of data frame with all rows
# data.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns
# data.iloc[0:5, 5:8] # first 5 rows and 5th, 6th, 7th columns of data frame
#
#
# #--------------------------------------------
# #         Selections using loc
# #--------------------------------------------
#
# # Select rows with index values 'Andrade' and 'Veness', with all columns between 'city' and 'email'
# data.loc[['Andrade', 'Veness'], 'city':'email']
# # Select same rows, with just 'first_name', 'address' and 'city' columns
# data.loc['Andrade':'Veness', ['first_name', 'address', 'city']]
#
# # Change the index to be based on the 'id' column
# data.set_index('id', inplace=True)
# # select the row with 'id' = 487
# data.loc[487]

# %%
import pandas as pd
import numpy as np
import random

# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("uk-500.csv")
# df = pd.read_csv('https://s3-eu-west-1.amazonaws.com/shanebucket/downloads/uk-500.csv')

# %%
df.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web
# 0  http://www.alandrosenburgcpapc.co.uk
# 1     http://www.capgeminiamerica.co.uk
# 2      http://www.elliottjohnwesq.co.uk
# 3          http://www.mcmahanbenl.co.uk
# 4        http://www.champagneroom.co.uk

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
# first_name      500 non-null object
# last_name       500 non-null object
# company_name    500 non-null object
# address         500 non-null object
# city            500 non-null object
# county          500 non-null object
# postal          500 non-null object
# phone1          500 non-null object
# phone2          500 non-null object
# email           500 non-null object
# web             500 non-null object
# dtypes: object(11)
# memory usage: 43.1+ KB

# %% [markdown]
# ### 1. Selecting data using “iloc” indexer
# *integer location-based indexer*

# %%
df.iloc[0] # -- First row, index=0
# Out:
# first_name                                   Aleshia
# last_name                                 Tomkiewicz
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# Name: 0, dtype: object

# %%
df.iloc[2] # -- Third row, index=2
# Out:
# first_name                                France
# last_name                                Andrade
# company_name                 Elliott, John W Esq
# address                             8 Moor Place
# city              East Southbourne and Tuckton W
# county                               Bournemouth
# postal                                   BH6 3BE
# phone1                              01347-368222
# phone2                              01935-821636
# email                 france.andrade@hotmail.com
# web             http://www.elliottjohnwesq.co.uk
# Name: 2, dtype: object

# %%
df.iloc[:, 0].head() # -- First column of the dataframe
# Out:
# 0    Aleshia
# 1       Evan
# 2     France
# 3    Ulysses
# 4     Tyisha
# Name: first_name, dtype: object

# %%
df.iloc[:, 0:2].head() # -- First two columns
# Out:
#   first_name   last_name
# 0    Aleshia  Tomkiewicz
# 1       Evan   Zigomalas
# 2     France     Andrade
# 3    Ulysses   Mcwalters
# 4     Tyisha      Veness

# %%
# 1st, 4th, 7th, 25th row + 1st 6th 7th columns
df.iloc[[0, 3, 6, 24], [0, 5, 6]]
# Out:
#    first_name        county    postal
# 0     Aleshia          Kent   CT2 7PP
# 3     Ulysses  Lincolnshire  DN36 5RP
# 6        Marg   Southampton  SO14 3TY
# 24       Tess   West Sussex  PO19 1RH

# %%
# first 5 rows and 5th, 6th, 7th columns of data frame
df.iloc[0:5, 4:7]
# Out:
#                              city           county    postal
# 0               St. Stephens Ward             Kent   CT2 7PP
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT

# %% [markdown]
# ### 2. Selecting data using “loc” indexer
# *location-based indexer*

# %%
# Select rows with index values 'Andrade' and 'Veness', with all columns between 'city' and 'email'

# %%
df.set_index("last_name", inplace=True)
df.head()
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# Tomkiewicz  01835-703597  01944-369967     atomkiewicz@hotmail.com
# Zigomalas   01937-864715  01714-737668    evan.zigomalas@gmail.com
# Andrade     01347-368222  01935-821636  france.andrade@hotmail.com
# Mcwalters   01912-771311  01302-601380         ulysses@hotmail.com
# Veness      01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                              web
# last_name
# Tomkiewicz  http://www.alandrosenburgcpapc.co.uk
# Zigomalas      http://www.capgeminiamerica.co.uk
# Andrade         http://www.elliottjohnwesq.co.uk
# Mcwalters           http://www.mcmahanbenl.co.uk
# Veness            http://www.champagneroom.co.uk

# %%
df.loc['Andrade']
# Out:
# first_name                                France
# company_name                 Elliott, John W Esq
# address                             8 Moor Place
# city              East Southbourne and Tuckton W
# county                               Bournemouth
# postal                                   BH6 3BE
# phone1                              01347-368222
# phone2                              01935-821636
# email                 france.andrade@hotmail.com
# web             http://www.elliottjohnwesq.co.uk
# Name: Andrade, dtype: object

# %%
# Select rows with index values 'Andrade' and 'Veness', with all columns between 'city' and 'email'
df.loc[['Andrade', 'Veness'], 'city':'email']
# Out:
#                                      city         county   postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth  BH6 3BE
# Veness         Greets Green and Lyng Ward  West Midlands  B70 9DT
#
#                  phone1        phone2                       email
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com

# %%
# Select same rows, with just 'first_name', 'address' and 'city' columns
df.loc[['Andrade', 'Veness'], ['first_name', 'address', 'city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %%
# Change the index to be based on the 'id' column

df['id'] = [random.randint(0,1000) for x in range(df.shape[0])]

df.set_index('id', inplace=True)

# %%
df.head()
# Out:
#     first_name             company_name            address  \
# id
# 814    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# 437       Evan       Cap Gemini America        5 Binney St
# 101     France      Elliott, John W Esq       8 Moor Place
# 472    Ulysses           Mcmahan, Ben L      505 Exeter Rd
# 631     Tyisha           Champagne Room  5396 Forth Street
#
#                                city           county    postal        phone1  \
# id
# 814               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 437                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 101  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 472              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 631      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#            phone2                       email  \
# id
# 814  01944-369967     atomkiewicz@hotmail.com
# 437  01714-737668    evan.zigomalas@gmail.com
# 101  01935-821636  france.andrade@hotmail.com
# 472  01302-601380         ulysses@hotmail.com
# 631  01290-367248   tyisha.veness@hotmail.com
#
#                                       web
# id
# 814  http://www.alandrosenburgcpapc.co.uk
# 437     http://www.capgeminiamerica.co.uk
# 101      http://www.elliottjohnwesq.co.uk
# 472          http://www.mcmahanbenl.co.uk
# 631        http://www.champagneroom.co.uk

# %%
# select the row with 'id' = 281
df.loc[281]
# Out:
# first_name                              Margarett
# company_name                 Reid, Carleton B Esq
# address                               3 August Rd
# city                  Maybury and Sheerwater Ward
# county                                     Surrey
# postal                                   GU21 5QL
# phone1                               01670-813697
# phone2                               01903-424890
# email                         margarett@gmail.com
# web             http://www.reidcarletonbesq.co.uk
# Name: 281, dtype: object

# %% [markdown]
# ## Next: Missing Data
